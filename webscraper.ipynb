# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import datetime

# %%
url = "https://www.amazon.com/Samsung-Galaxy-Tab-64-W129243165/dp/B0G2RNZXLZ/ref=sr_1_10?_encoding=UTF8&content-id=amzn1.sym.f0670b1b-e1fd-4c67-a2b1-b8a347243628&dib=eyJ2IjoiMSJ9.7yOrlIfk_tlEZy-WRmY6RPtjPTdh24RkqhlYtuciI5zlaU6a3ndlfLcuILJdtSP5h3atW4rugKXtLamahVsTsA-f26syEPdpmSmi2g5DuqwdhmZMZv-qWyFK3ZzZKYe6_DhoTGERtotSizXth3MkGUu-ovW6lVS0L9-ayRZrMGxlC35UAF__xQpOlISGB1qt13ibepCjh-JJojCd4u92R5LI866IV9sbywDGJTfsRB8.R-X2KyTSX0LIpxP_qzFG3_H_9SJxOlO08US8tjNll64&dib_tag=se&keywords=electronic+tablets&pd_rd_r=d09701b0-ea2f-4159-b467-d0a4fb81135f&pd_rd_w=X2lIy&pd_rd_wg=hl11s&qid=1774237860&sr=8-10"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/120 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

page = requests.get(url,headers=headers)
soup = BeautifulSoup(page.content,"html.parser")
soup = BeautifulSoup(soup.prettify(),"html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
title = soup.find(id = "productTitle").get_text()
price = soup.find(class_ = "aok-offscreen").get_text()

title = title.strip()
price = price.strip()[1:]

# %%
print(title)
print(price)
# Out:
# Samsung Galaxy Tab A 64 GB - 8.7 Tablet - A11, W129243165 (Tablet - A11)
# 244.60

# %%
today = datetime.date.today()

# %%
Commented this to not accidently delete all 

import csv

titles = ['Product','Price','Date']
data = [title, price, today]


if not os.path.exists("Amazon_Webscraper.csv"):

    with open("Amazon_Webscraper.csv","w", newline="",encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(titles)
        writer.writerow(data)
else:
    with open('Amazon_Webscraper.csv', 'a+', newline="", encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():

    from bs4 import BeautifulSoup
    import pandas as pd
    import requests
    import time
    import datetime

    url = "https://www.amazon.com/Samsung-Galaxy-Tab-64-W129243165/dp/B0G2RNZXLZ/ref=sr_1_10?_encoding=UTF8&content-id=amzn1.sym.f0670b1b-e1fd-4c67-a2b1-b8a347243628&dib=eyJ2IjoiMSJ9.7yOrlIfk_tlEZy-WRmY6RPtjPTdh24RkqhlYtuciI5zlaU6a3ndlfLcuILJdtSP5h3atW4rugKXtLamahVsTsA-f26syEPdpmSmi2g5DuqwdhmZMZv-qWyFK3ZzZKYe6_DhoTGERtotSizXth3MkGUu-ovW6lVS0L9-ayRZrMGxlC35UAF__xQpOlISGB1qt13ibepCjh-JJojCd4u92R5LI866IV9sbywDGJTfsRB8.R-X2KyTSX0LIpxP_qzFG3_H_9SJxOlO08US8tjNll64&dib_tag=se&keywords=electronic+tablets&pd_rd_r=d09701b0-ea2f-4159-b467-d0a4fb81135f&pd_rd_w=X2lIy&pd_rd_wg=hl11s&qid=1774237860&sr=8-10"


    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/120 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9"
    }

    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content,"html.parser")
    soup = BeautifulSoup(soup.prettify(),"html.parser")

    title = soup.find(id = "productTitle").get_text()
    price = soup.find(class_ = "aok-offscreen").get_text()

    title = title.strip()
    price = price.strip()[1:]
    today = datetime.date.today()

    import csv

    titles = ['Product','Price','Date']
    data = [title, price, today]

    with open("Amazon_Webscraper.csv","a+", newline="",encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv("Amazon_Webscraper.csv")
df
# Out:
#                                              Product  Price        Date
# 0  Samsung Galaxy Tab A 64 GB - 8.7 Tablet - A11,...  244.6  2026-03-23

# %%
while True:
    check_price()
    time.sleep(86400)

# %%
# Out:
# Empty DataFrame
# Columns: [Samsung Galaxy Tab A 64 GB - 8.7 Tablet - A11, W129243165 (Tablet - A11), 244.60, 2026-03-23]
# Index: []
